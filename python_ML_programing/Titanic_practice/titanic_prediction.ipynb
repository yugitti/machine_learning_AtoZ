# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
custom_style = {'axes.labelcolor': 'white',
                'xtick.color': 'white',
                'ytick.color': 'white'}
sns.set_style("darkgrid", rc=custom_style)
plt.style.use('dark_background')
from sklearn import  datasets

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
fig = plt.figure(figsize=(10,5),dpi=100)
sns.countplot('Pclass', data=df_train, hue='Sex', palette='pastel')

# %%
fig = plt.figure(figsize=(10,5),dpi=100)
sns.distplot(df_train['Age'].dropna(), bins=70)
# Out:
# /Users/yugi/.pyenv/versions/anaconda-4.0.0/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df = df_train.loc[:,['Age', 'Sex', 'Pclass', 'Survived']]

# %%
df = df.dropna()

# %%
fig = plt.figure(figsize=(10,5),dpi=100)
sns.countplot('Survived', data=df_train)

# %%
fig = plt.figure(figsize=(10,5),dpi=200)
sns.factorplot('Pclass', 'Survived', data=df_train, hue='Sex')

# %%
generations=[10,20,40,60,80]
sns.lmplot('Age','Survived',hue='Pclass',data=df_train,palette='pastel',x_bins=generations,hue_order=[1,2,3])

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
X_train = df_train.loc[:,['Age', 'Sex', 'Pclass', 'Fare', 'Survived']]

# %%
X_train_nonna = X_train.dropna()

# %%
X_train['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
X_train['Sex'][X_train['Sex'] == 'male'] = 0
X_train['Sex'][X_train['Sex'] == 'female'] = 1
# Out:
# /Users/yugi/.pyenv/versions/anaconda-4.0.0/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/yugi/.pyenv/versions/anaconda-4.0.0/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_train = X_train.dropna()

# %%
sns.lmplot('Age','Survived',hue='Sex',data=df_train,palette='pastel')

# %%
X_train.head()
# Out:
#     Age Sex  Pclass     Fare  Survived
# 0  22.0   0       3   7.2500         0
# 1  38.0   1       1  71.2833         1
# 2  26.0   1       3   7.9250         1
# 3  35.0   1       1  53.1000         1
# 4  35.0   0       3   8.0500         0

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf 
 
fit = smf.glm(formula='Survived ~ Age + Sex + Pclass + Fare', data=X_train, family=sm.families.Binomial())
res_fit = fit.fit()
print(res_fit.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  714
# Model:                            GLM   Df Residuals:                      709
# Model Family:                Binomial   Df Model:                            4
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -323.61
# Date:                Sun, 10 Jun 2018   Deviance:                       647.23
# Time:                        19:43:37   Pearson chi2:                     768.
# No. Iterations:                     5   Covariance Type:             nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.4698      0.525      4.707      0.000       1.442       3.498
# ...

# %%
X_train.head()
X_train['Intercept'] = 1.0
# Out:
# /Users/yugi/.pyenv/versions/anaconda-4.0.0/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_train.head()
# Out:
#     Age Sex  Pclass     Fare  Survived  Intercept
# 0  22.0   0       3   7.2500         0        1.0
# 1  38.0   1       1  71.2833         1        1.0
# 2  26.0   1       3   7.9250         1        1.0
# 3  35.0   1       1  53.1000         1        1.0
# 4  35.0   0       3   8.0500         0        1.0

# %%
X_train.astype(np.float64)
# Out:
#       Age  Sex  Pclass      Fare  Survived  Intercept
# 0    22.0  0.0     3.0    7.2500       0.0        1.0
# 1    38.0  1.0     1.0   71.2833       1.0        1.0
# 2    26.0  1.0     3.0    7.9250       1.0        1.0
# 3    35.0  1.0     1.0   53.1000       1.0        1.0
# 4    35.0  0.0     3.0    8.0500       0.0        1.0
# 6    54.0  0.0     1.0   51.8625       0.0        1.0
# 7     2.0  0.0     3.0   21.0750       0.0        1.0
# 8    27.0  1.0     3.0   11.1333       1.0        1.0
# 9    14.0  1.0     2.0   30.0708       1.0        1.0
# 10    4.0  1.0     3.0   16.7000       1.0        1.0
# 11   58.0  1.0     1.0   26.5500       1.0        1.0
# 12   20.0  0.0     3.0    8.0500       0.0        1.0
# 13   39.0  0.0     3.0   31.2750       0.0        1.0
# 14   14.0  1.0     3.0    7.8542       0.0        1.0
# 15   55.0  1.0     2.0   16.0000       1.0        1.0
# 16    2.0  0.0     3.0   29.1250       0.0        1.0
# ...

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf 

logit = sm.Logit(X_train['Survived'], X_train.loc[:,X_train.columns != 'Survived'].values.astype(np.float32))

# %%
logit_fit = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453242
#          Iterations 6

# %%
logit_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  714
# Model:                          Logit   Df Residuals:                      709
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 10 Jun 2018   Pseudo R-squ.:                  0.3290
# Time:                        23:04:53   Log-Likelihood:                -323.61
# converged:                       True   LL-Null:                       -482.26
#                                         LLR p-value:                 2.020e-67
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0367      0.008     -4.780      0.000      -0.052      -0.022
# x2             2.5182      0.208     12.115      0.000       2.111       2.926
# ...
